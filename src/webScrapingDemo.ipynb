# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/activity06_webScCsv_starter/blob/main/src/webScrapingDemo.ipynb)

# %% [markdown]
# # Activity 6

# %% [markdown]
# ## Muhammed Bello

# %%
import requests
url = "https://en.wikipedia.org/wiki/Tadasu_no_Mori"
headers = {
	"User-Agent": "CMPSC105 Data Gathering Demo"
}
r = requests.get(url, headers=headers)
print(r.status_code)
print(r.text[:1000]) # print first 1000 characters
# Out:
# 200
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Tadasu no Mori - Wikipedia</title>
# ...

# %%
#  Run the codes above.
# : Change the URL to scrape a different Wikipedia page. For example: https://en.wikipedia.org/wiki/Linear_regression
#  Retrieve the page that you selected using the codes above.

# %%
import requests
url = "https://en.wikipedia.org/wiki/Tadasu_no_Mori"
headers = {
	"User-Agent": "CMPSC105 Data Gathering Demo"
}
r = requests.get(url, headers=headers)
print(r.status_code)
print(r.text[:1000]) # print first 1000 characters
# Out:
# 200
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Tadasu no Mori - Wikipedia</title>
# ...
