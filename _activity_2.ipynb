# %% [markdown]
# <a href="https://colab.research.google.com/github/bello1987/muhammed/blob/main/_activity_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# ---
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/activity02_dataDisplay_starter/blob/main/src/data_display_activity.ipynb)

# %% [markdown]
# # Class Activity

# %% [markdown]
# ## Goals
#
# 1. Look at code that can generate common data displays
# 2. Modify code that can generate common data displays
# 3. Describe how common data displays are able to convey information that was not apparent in raw data

# %% [markdown]
# -  Run the first code cell
#
# -  In the variable explorer (`{x}`), what Type does the variable `df` have? Write your response here: this is a panda data frame.
#
# -  In the variable explorer (`{x}`), what Shape does the variable `df` have? Write your response here: it has (5,2)
#
# -  In the variable explorer (`{x}`), hover over the variable `df` to see the values. What relationship do the values have to the Shape of `df`? Explain what the shape means. Write your response here: they are 5 rows and 2 colums.
#
# -  Looking at the rest of the code cells that can generate figures, what patterns do you see repeated in the code? Write your response here: all the code has the pti,figures and label functions. yes the figure makes it easy to compare the values to understand.
#
# -  Run the code cells, stopping once you reach the next section. Examine the figures.
#
# -  Explain what relationship exists between the reddish code in quotes and the figures that are generated. Write your response here:
#
# - : Find a piece of code where a marker was explicitly specified. Change the marker to an upward triangle, a square, and a star based on [the matplotlib documentation](https://matplotlib.org/stable/api/markers_api.html) and rerun the code.
#
# -  Overall, do these figures reveal anything about this data that was not so apparent when looking at `df`?  Write your response here:
#
# - Now, move on to the next section

# %% [markdown]
# The data table below shows how many millions of prescriptions are obtained from various sources in the United States annually.
#
# | Drug Source | Num Prescriptions |
# |-------------|-------------------|
# | Traditional | 914 |
# | Independent | 666 |
# | MassMerch   | 238 |
# | SuperMarket | 221 |
# | MailOrder   | 86  |

# %%
#| label: pandas-dataframe

# import pandas and make dataframe

import pandas as pd

data = {'Drug Source': ['Traditional', 'Independent', 'MassMerch', 'SuperMarket', 'MailOrder'],
        'Num Prescriptions': [914, 666, 238, 221, 86]}
df = pd.DataFrame(data)

df
# Out:
#    Drug Source  Num Prescriptions
# 0  Traditional                914
# 1  Independent                666
# 2    MassMerch                238
# 3  SuperMarket                221
# 4    MailOrder                 86

# %%
#| label: dot-plot

import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is already created in the previous code
plt.figure()
plt.scatter(df['Num Prescriptions'], df['Drug Source'])
plt.xlabel('Number of Prescriptions')
plt.ylabel('Drug Source')
plt.title('Drug Source vs. Number of Prescriptions')
plt.grid(True)
plt.show()

# %%
#| label: pie-chart

import matplotlib.pyplot as plt

# Assuming df is already created in the previous code

plt.figure()
plt.pie(df['Num Prescriptions'], labels=df['Drug Source'])
plt.title('Drug Source')
plt.show()

# %%
#| label: histogram

import matplotlib.pyplot as plt

# Assuming df is already created in the previous code

plt.figure()
plt.hist(df['Num Prescriptions'], bins=20)
plt.xlabel('Number of Prescriptions')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Prescriptions')
plt.show()

# %%
#| label: line-plot

import matplotlib.pyplot as plt

# Assuming df is already created in the previous code
plt.figure()  # Adjust figure size for better visualization
plt.plot(df['Drug Source'], df['Num Prescriptions'], marker='+', linestyle='-')
plt.xlabel('Drug Source')
plt.ylabel('Number of Prescriptions (Millions)')
plt.title('Number of Prescriptions by Drug Source')
plt.grid(True, linestyle='--', alpha=0.7)  # Add a grid for better readability
plt.xticks(rotation=45) # Rotate x-axis labels for better visibility
plt.show()

# %%
#| label: box

import matplotlib.pyplot as plt

# Assuming df is already created in the previous code
plt.figure()
plt.boxplot(df['Num Prescriptions'])  # Create the boxplot
plt.xlabel('Number of Prescriptions')
plt.title('Box Plot of Number of Prescriptions')
plt.show()

# %% [markdown]
# # Movie Rating Data

# %% [markdown]
# -  Check out this [other data set](https://files.grouplens.org/datasets/movielens/ml-100k-README.txt) of movie ratings from 1997-98 of over 1000 movies!
#
# -  Re-create a dot plot, a pie chart, histogram, line plot, and box plot with the data found below. Specifically, copy the code cells above (don't delete the ones above) and make necessary adjustments to use the new data. The new data does not have 'Num Prescriptions' or 'Drug Source', but it does have 'User ID', 'Movie ID', 'Rating', 'Timestamp'. The goal here is to **explore the data** using common display types.
#
# -  In the variable explorer (`{x}`), what Shape does the new variable `df` have? Write your response here: the df have (100000,4) that is 100000 rows and 4 conlums.
#
# -  In the variable explorer (`{x}`), hover over the new variable `df` to see the values. What relationship do the values have to the Shape of `df`? Write your response here: Each row represent a specific variable.User ID,Movie ID, Rating and TimeStamp.
#
# -  Overall, do these figures reveal anything about this data that was not so apparent when looking at `df`?  Write your response here: yes the plots revealed the rating of some certian values like the 3, amd 4 which are not immediately obvious when looking at the rows of data.
#
# -  So far, what is the value of data exploration through data display? Data display helps to identify patterns outliers quickly. it makes dataset easier to understand than table alone.
#
# - Reference: [Herlocker, J., Konstan, J., Borchers, A., Riedl, J.. An Algorithmic Framework for Performing Collaborative Filtering. Proceedings of the 1999 Conference on Research and Development in Information Retrieval. Aug. 1999.](https://grouplens.org/datasets/movielens/)

# %%
# import pandas and make dataframe

import pandas as pd

df = pd.read_csv(
    'https://files.grouplens.org/datasets/movielens/ml-100k/u.data',
    sep='\t',
    names=['User ID', 'Movie ID', 'Rating', 'Timestamp'],
    skiprows=0, # Skip header if file has one
)

print(df.head()) # Display the first few rows of the DataFrame
# Out:
#    User ID  Movie ID  Rating  Timestamp
# 0      196       242       3  881250949
# 1      186       302       3  891717742
# 2       22       377       1  878887116
# 3      244        51       2  880606923
# 4      166       346       1  886397596
