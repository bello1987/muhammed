# %% [markdown]
# <a href="https://colab.research.google.com/github/bello1987/muhammed/blob/main/Copy_of_storyProblem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# muhammed belo

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/activity01_starter/blob/main/src/storyProblem.ipynb)

# %%
IRST_VALUE = 3
SECOND_VALUE = 5

# %%
print("Completed story problem:")
print= 3^5
# Out:
# Completed story problem:

# %%
student_answer = 243

# %%
correct_result = fx = 3

# %%
if student_answer == correct_result:
    print = 3
else:
    print= 5
